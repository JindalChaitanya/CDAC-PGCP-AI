# %% [markdown]
# # Assignment 5

# %% [markdown]
# ## Submitted by Chaitanya Jindal

# %% [markdown]
# #### Q1. Write a Python program to read an entire text file.

# %% [markdown]
# #### Q2. Write a program that counts lines and characters in a file. Create a Python module called `mymod.py` that exports:
# - countLines(name): counts the number of lines in a file
# - countChars(name): counts the number of characters in a file
# - test(name): calls both functions with the given filename.

# %% [markdown]
# #### Q3. Test your `mymod` module interactively using `from` to load the exports directly, first by name and then using `from *`.

# %% [markdown]
# #### Q4. Modify the `mymod` module so that the `test()` function runs automatically only when the module is executed as a script using `__name__ == "__main__"`.

# %% [markdown]
# #### Q5. Write another module `myclient.py` that imports `mymod` and tests its functions. Test both variations:
# - importing using `import`
# - importing using `from`.

# %% [markdown]
# #### Q6. Create a package named `mypkg`, move `mymod.py` into it, and import it using `import mypkg.mymod`.

# %% [markdown]
# #### Q7. Experiment with module reloads using the `changer.py` example by repeatedly modifying the function behavior without restarting the Python interpreter.
